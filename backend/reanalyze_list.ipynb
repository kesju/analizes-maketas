# %%
import subprocess
from pathlib import Path
import argparse
import json
import time

from util_list import collect_filenames, runtime

Duomenu_aplankas = '/home/kesju/DI/MAKETAS'   # arba variantas: UBUNTU, be Docker

# Vietinės talpyklos aplankas
db_folder = 'analizes-maketas'

# Duomenų aplankas
rec_folder = 'data'

# Analizės rezultatų aplankas
rsl_folder = 'results'

db_path = Path(Duomenu_aplankas, db_folder, rec_folder) 
print( 'Duomenų aplankas:', db_path)

rsl_path = Path(Duomenu_aplankas, db_folder, rsl_folder) 
print( 'Rezultatų aplankas:', rsl_path)

# Variantas - užduotas sarašas


FileNames = [
1642627.410,
1626931.201,
1626934.963,
1630693.635,
1630714.569,
1630715.664,
1630718.396,
]

# FileNames = [
# 1630714.569,
# 1630715.664
# ]

# FileNames = [1630718.396]

file_names=["%.3f" % i for i in FileNames]

channelCount = 1
recordingId = '11111'

# Variantas - sudaro sąrašą iš duomenų aplanko
file_names = collect_filenames(db_path)
print("\nDuomenų sąrašas:")
print(file_names)

# CIKLAS PER EKG ĮRAŠUS

start_time = time.time()

for index, fname in enumerate(file_names):    
    fpath = Path(db_path, fname)
    print("\nĮrašas nr.:", index, "file name:", fname)
    # print("Įrašas:", fpath)

    # Call the program with the arguments
    program_args = ['python', 'analysis/analyse.py', fpath, '--channelCount', str(channelCount), '--recordingId', recordingId]
    result = subprocess.run(program_args, stdout=subprocess.PIPE)
    # output = result.stdout.decode('utf-8')
    # print(output)
    end_time = time.time()
    runtime(end_time-start_time)
# Out:
# Duomenų aplankas: /home/kesju/DI/MAKETAS/analizes-maketas/data
# Rezultatų aplankas: /home/kesju/DI/MAKETAS/analizes-maketas/results
#
# Duomenų sąrašas:
# ['1632342.032', '1638818.315', '1626934.963', '1626931.201', '1638801.784', '1631029.786', '1638818.942', '1633405.853', '1637622.288', '1630693.635', '1630718.396', '1631039.923', '1630714.569', '1630734.526', '1633584.898', '1634112.089', '1636451.860', '1631083.411', '1630729.576', '1642627.410', '1633428.560', '1630721.490', '1630715.664', '1631139.883', '1630735.143']
#
# Įrašas nr.: 0 file name: 1632342.032
# Runtime: 00:00:42
#
# Įrašas nr.: 1 file name: 1638818.315
# Runtime: 00:01:28
#
# Įrašas nr.: 2 file name: 1626934.963
# Runtime: 00:02:29
#
# Įrašas nr.: 3 file name: 1626931.201
# Runtime: 00:03:44
#
# Įrašas nr.: 4 file name: 1638801.784
# Runtime: 00:04:58
#
# Įrašas nr.: 5 file name: 1631029.786
# Runtime: 00:06:32
#
# Įrašas nr.: 6 file name: 1638818.942
# Runtime: 00:07:43
#
# Įrašas nr.: 7 file name: 1633405.853
# Runtime: 00:08:48
#
# Įrašas nr.: 8 file name: 1637622.288
# Runtime: 00:09:57
#
# Įrašas nr.: 9 file name: 1630693.635
# Runtime: 00:10:53
#
# Įrašas nr.: 10 file name: 1630718.396
# Runtime: 00:11:55
#
# Įrašas nr.: 11 file name: 1631039.923
# Runtime: 00:13:06
#
# Įrašas nr.: 12 file name: 1630714.569
# Runtime: 00:13:56
#
# Įrašas nr.: 13 file name: 1630734.526
# Runtime: 00:15:25
#
# Įrašas nr.: 14 file name: 1633584.898
# Runtime: 00:16:25
#
# Įrašas nr.: 15 file name: 1634112.089
# Runtime: 00:17:20
#
# Įrašas nr.: 16 file name: 1636451.860
# Runtime: 00:18:22
#
# Įrašas nr.: 17 file name: 1631083.411
# Runtime: 00:19:52
#
# Įrašas nr.: 18 file name: 1630729.576
# Runtime: 00:20:56
#
# Įrašas nr.: 19 file name: 1642627.410
# Runtime: 00:21:53
#
# Įrašas nr.: 20 file name: 1633428.560
# Runtime: 00:23:13
#
# Įrašas nr.: 21 file name: 1630721.490
# Runtime: 00:24:11
#
# Įrašas nr.: 22 file name: 1630715.664
# Runtime: 00:25:03
#
# Įrašas nr.: 23 file name: 1631139.883
# Runtime: 00:26:29
#
# Įrašas nr.: 24 file name: 1630735.143
# Runtime: 00:27:31
