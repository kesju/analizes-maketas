# %%
import subprocess
from pathlib import Path
import argparse
import json
import time

from util_list import collect_filenames, runtime

Duomenu_aplankas = '/home/kesju/DI'   # arba variantas: UBUNTU, be Docker

# Vietinės talpyklos aplankas
db_folder = 'MAKETAS'

# Duomenų aplankas
rec_folder = 'data'

# Analizės rezultatų aplankas
rsl_folder = 'results'

db_path = Path(Duomenu_aplankas, db_folder, rec_folder) 
print( 'Duomenų aplankas:', db_path)

rsl_path = Path(Duomenu_aplankas, db_folder, rsl_folder) 
print( 'Rezultatų aplankas:', rsl_path)

# Variantas - užduotas sarašas


FileNames = [
1642627.410,
1626931.201,
1626934.963,
1630693.635,
1630714.569,
1630715.664,
1630718.396,
]

# FileNames = [
# 1630714.569,
# 1630715.664
# ]

# FileNames = [1630718.396]

file_names=["%.3f" % i for i in FileNames]

channelCount = 1
recordingId = '11111'

# Variantas - sudaro sąrašą iš duomenų aplanko
file_names = collect_filenames(db_path)
print("\nDuomenų sąrašas:")
print(file_names)

# CIKLAS PER EKG ĮRAŠUS

start_time = time.time()

for index, fname in enumerate(file_names):    
    fpath = Path(db_path, fname)
    print("\nĮrašas nr.:", index, "file name:", fname)
    # print("Įrašas:", fpath)

    # Call the program with the arguments
    program_args = ['python', 'analysis/analyse.py', fpath, '--channelCount', str(channelCount), '--recordingId', recordingId]
    result = subprocess.run(program_args, stdout=subprocess.PIPE)
    # output = result.stdout.decode('utf-8')
    # print(output)
    end_time = time.time()
    runtime(end_time-start_time)
# Out:
# Duomenų aplankas: /home/kesju/DI/MAKETAS/data
# Rezultatų aplankas: /home/kesju/DI/MAKETAS/results
#
# Duomenų sąrašas:
# ['1631036.053', '21302.002', '1633444.221', '1631050.134', '1642635.482', '22102.002', '1637625.426', '21901.001', '1637628.402', '22003.003', '1642634.862', '1633434.198', '21902.002', '1643070.532', '1632252.683', '1632730.004', '1632730.631', '1633548.426', '1631084.656', '1631075.918', '21502.002', '1631132.986', '1631702.918', '10901.001', '1631066.094', '1630806.998', '1630797.676', '1630869.824', '1633395.185', '10801.001', '1642632.378', '20502.002', '20902.002', '11901.001', '1631080.771', '1643078.826', '1631075.042', '10501.001', '1634736.586', '1638818.315', '12203.003', '23001.001', '10301.001', '10502.002', '1630844.567', '1630735.765', '10302.002', '1626934.963', '1626931.201', '1638801.784', '11103.003', '1634648.967', '10303.003', '1631059.832', '23003.003', '1631137.375', '20101.001', '1631071.960', '10003.003', '12201.001', '1631078.776', '1630720.872', '10803.003', '20803.003', '1631068.862', '11201.001', '1637166.430', '1633406.480', '1631001.238', '22803.003', '10001.001', '1638799.296', '1631072.976', '1643061.340', '1631044.186', '12101.001', '1632728.750', '1630733.908', '1631043.288', '20302.002', '1637628.331', '1636490.526', '1631136.748', '20303.003', '1638818.942', '11602.002', '1631027.284', '1632731.258', '21903.003', '20503.003', '1636596.765', '1631027.890', '1637626.680', '1633434.823', '1631074.415', '1631130.477', '10101.001', '1632923.661', '20001.001', '23103.003', '1636414.518', '22302.002', '20201.001', '1637622.288', '1630859.890', '1630693.635', '1631087.069', '1631076.286', '1630726.223', '1630757.924', '1631054.200', '1633427.309', '1631135.494', '12402.002', '1631085.830', '1632133.116', '1637619.150', '1638817.688', '1631077.360', '1630947.302', '1631077.167', '1636451.235', '10602.002', '1631082.735', '1631131.731', '1631072.980', '1630946.757', '1633356.900', '11202.002', '1631129.850', '1630718.396', '1631087.691', '1631079.524', '1631099.746', '1636495.646', '1630944.253', '11402.002', '11701.001', '1637631.801', '11203.003', '22301.001', '1631071.099', '20202.002', '1630759.170', '1631000.593', '1631078.608', '1631086.524', '20802.002', '1631073.608', '20102.002', '21503.003', '1637624.172', '1630719.632', '1631033.093', '12102.002', '1631056.479', '23203.003', '1631126.715', '1631075.662', '11501.001', '1631084.032', '23301.001', '1631039.923', '1630984.331', '1630795.799', '21501.001', '10802.002', '1631077.172', '1631077.534', '1631141.137', '1637584.866', '1631064.840', '1633396.439', '1630939.875', '1631061.710', '1630725.864', '1633443.596', '20203.003', '20903.003', '1631079.236', '23303.003', '12401.001', '1630714.569', '1632123.567', '1637584.237', '23202.002', '21402.002', '1631080.484', '1631002.473', '1633540.147', '1631076.910', '1637622.914', '21202.002', '12403.003', '10002.002', '1631057.738', '1631119.188', '1642628.030', '20901.001', '11803.003', '1630876.859', '11802.002', '1631070.122', '21303.003', '12301.001', '1637189.804', '20301.001', '12103.003', '1630763.516', '21401.001', '1630734.526', '1631082.791', '10902.002', '1631069.221', '1631069.482', '20003.003', '1633387.028', '21301.001', '1625408.182', '1636423.936', '11601.001', '22103.003', '1631079.642', '1626941.468', '23302.002', '12303.003', '21403.003', '1630722.107', '1631083.357', '1626924.927', '1631063.587', '20002.002', '1630807.618', '1632729.377', '1631081.108', '23201.001', '11502.002', '1631055.852', '11903.003', '1631052.950', '1631068.242', '1631047.940', '10102.002', '22802.002', '1631083.411', '1631078.157', '1642633.618', '1630729.576', '1631113.542', '23402.002', '1630810.723', '1637585.491', '10103.003', '1631086.728', '1643064.468', '1631115.424', '11703.003', '1631141.764', '1643065.093', '1630943.629', '1631029.205', '22101.001', '1631012.235', '12202.002', '1630986.207', '21002.002', '11403.003', '21003.003', '1630733.290', '1631086.104', '1631039.807', '21001.001', '11303.003', '1642627.410', '1636593.000', '1631077.984', '1638806.132', '1625402.027', '1631132.359', '1630768 ...
#
# Įrašas nr.: 0 file name: 1631036.053
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 67
#      63 # print("Įrašas:", fpath)
#      64
#      65 # Call the program with the arguments
#      66 program_args = ['python', 'analysis/analyse.py', fpath, '--channelCount', str(channelCount), '--recordingId', recordingId]
# ---> 67 result = subprocess.run(program_args, stdout=subprocess.PIPE)
#      68 # output = result.stdout.decode('utf-8')
#      69 # print(output)
#      70 end_time = time.time()
#
# File ~/miniconda3/envs/ecg_lnx38/lib/python3.8/subprocess.py:495, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
# --> 495         stdout, stderr = process.communicate(input, timeout=timeout)
#     496     except TimeoutExpired as exc:
#     497         process.kill()
#
# File ~/miniconda3/envs/ecg_lnx38/lib/python3.8/subprocess.py:1015, in Popen.communicate(self, input, timeout)
#    1013     self._stdin_write(input)
#    1014 elif self.stdout:
# -> 1015     stdout = self.stdout.read()
#    1016     self.stdout.close()
#    1017 elif self.stderr:
#
# KeyboardInterrupt:
